# %% [markdown]
# ### Load your Libraries

# %%
# Load Azure Libaries
from azureml.core import Workspace, Datastore, Dataset, Experiment, Environment
from azureml.core.authentication import InteractiveLoginAuthentication
import logging
import pandas as pd
import numpy as np
import json
import os

#Load Libraries for Deployment
from azureml.core.model import Model
from azureml.pipeline.steps import PythonScriptStep
from azureml.contrib.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data.data_reference import DataReference
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.pipeline.core import Pipeline, PipelineData, PublishedPipeline, PipelineEndpoint,PipelineParameter,PipelineRun
from azureml.core.runconfig import RunConfiguration, CondaDependencies, DEFAULT_CPU_IMAGE, DEFAULT_GPU_IMAGE
from azureml.widgets import RunDetails

# %% [markdown]
# ### Check your version of the AzureML Python SDK

# %%
print("You are currently using version " + azureml.core.VERSION + " of the Azure ML SDK")
# Out:
# You are currently using version 1.9.0 of the Azure ML SDK

# %% [markdown]
# ### Set your Workspace
# When performing this step for the first time, you will be asked to sign in using a hyperlink and a code generated below.<br>You will be asked to log in every so often depending on your organization.<br>  This connects your notebook to your Azure Machine Learning Service Workspace.

# %%
# Retrieve your workspace from config
ws = Workspace.from_config()

# %% [markdown]
# ### Set your Datastore
# A Datastore is a pointer to an Azure Storage Account or Azure SQL Database that links to your AMLS Workspace.<p>

# %%
# Retrieve your Datastore 
datastore_name = "teaching_datalake"  # CHANGE THIS
datastore = Datastore.get(ws, datastore_name)

# %% [markdown]
# ### Set your Remote Compute Target

# %%
# Retrieve your Compute Target for Running AutoML Remotely
from azureml.core.compute import ComputeTarget
compute_name = 'lp-training' # CHANGE HERE
compute_target = ComputeTarget(ws, compute_name)

# %% [markdown]
# ### Retrieve your Model

# %%
model_name = 'AutoML_Titanic_Classification' 
model = Model(ws, model_name)

# %% [markdown]
# ### Retrieve your Environment

# %%
environment_name = 'automl-environment'  # CHANGE THIS
environment = Environment.get(ws, environment_name)

# %% [markdown]
# ### Set your Dataset

# %%
# if we have the dataset existing already, reference it below
dataset_name = "titanic_training_transformed_automl"
dataset = Dataset.get_by_name(ws, dataset_name, version='latest')

# %%
# Set your dataset as named input to pass through the pipeline
named_input = dataset.as_named_input(dataset_name)

# %% [markdown]
# ### Create a Dataset Registration Script, a Scoring Script, and a Data Output Script for your Pipeline

# %%
# Create a folder on your local directory to hold all of your items
os.makedirs('AutoML_Retraining', exist_ok=True)

# %% [markdown]
# ### Create your Dataset Registration Step

# %%
# Create a Run Configuration with a Docker Container and your environment settings for your Data Transfer Step
run_config = RunConfiguration()
run_config.environment = environment
run_config.environment.docker.enabled = True
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE # Use DEFAULT_GPU_IMAGE for Deep Learning Jobs

# %%
cd = CondaDependencies.create(pip_indexurl="https://azuremlsdktestpypi.azureedge.net/datasets_uploading",                               
                              pip_packages=['azureml-core<0.1.10', 'azureml-dataprep'],
                              conda_packages=['numpy==1.16.2','pandas==0.23.4']) 
rc = RunConfiguration(conda_dependencies=cd)
rc.environment.docker.enabled = True
rc.environment.docker.base_image = DEFAULT_CPU_IMAGE

# %%
# %%writefile AutoML_Retraining/AutoML_Dataset_Registration.py
# ---------------------------------------------------------
# Copyright (c) Microsoft Corporation. All rights reserved.
# ---------------------------------------------------------
# Load in Libaries
import pandas as pd
import numpy as np
import json
import os
import math
import argparse
from azureml.core import Run
from azureml.core import Workspace, Datastore, Dataset, Experiment, Environment

parser = argparse.ArgumentParser()
parser.add_argument("--datastore_name", dest="datastore_name", required=True)
parser.add_argument("--dataset_name", dest="dataset_name", required=True)
args = parser.parse_args()

print("Argument 1(datastore_name): %s" % args.datastore_name)
print("Argument 2(dataset_name): %s" % args.dataset_name)

# Set Workspace from Run Context
ws = Run.get_context().experiment.workspace


# Retrieve your Datastore
datastore_name = args.datastore_name
datastore = Datastore.get(ws, datastore_name)
print('Datastore Set')

dataset = Dataset.get_by_name(ws, name=args.dataset_name)
DF = dataset.to_pandas_dataframe()

#Dataset.Tabular.register_pandas_dataframe(DF, datastore, args.dataset_name, show_progress=True)

print('Dataset Registered')
# Out:
# Overwriting AutoML_Retraining/AutoML_Dataset_Registration.py

# %%
register_dataset_step = PythonScriptStep(script_name="AutoML_Dataset_Registration.py",
                                       source_directory = 'AutoML_Retraining',
                                       name="Register_AutoML_Dataset",
                                       allow_reuse=False,
                                       arguments=["--datastore_name", datastore_name, 
                                                  "--dataset_name", dataset_name],
                                       inputs=[],
                                       compute_target=compute_target,
                                       runconfig=rc)

# %% [markdown]
# ### Create your AutoML Model Training Step

# %%
from azureml.train.automl import AutoMLConfig
from azureml.pipeline.steps import AutoMLStep

target_column_name = 'Survived'


automl_settings = {
    "iteration_timeout_minutes": 15,
    "experiment_timeout_hours": 0.5,
    "n_cross_validations": 3,
    "primary_metric": 'accuracy',
    "max_concurrent_iterations": 3,
    "max_cores_per_iteration": -1,
    "verbosity": logging.INFO,
    "enable_early_stopping": True
}

automl_config = AutoMLConfig(task = 'classification',
                             debug_log = 'automl_errors.log',
                             path = ".",
                             compute_target=compute_target,
                             training_data = dataset,
                             label_column_name = target_column_name,
                             **automl_settings
                            )

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=datastore,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=datastore,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=False)

# %% [markdown]
# ### Create your Model Registration Step

# %%
# %%writefile AutoML_Retraining/AutoML_Model_Registration.py
from azureml.core.model import Model, Dataset
from azureml.core.run import Run, _OfflineRun
from azureml.core import Workspace
import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--model_name", dest="model_name", required=True)
parser.add_argument("--model_path", dest="model_path", required=True)
parser.add_argument("--dataset_name", dest="dataset_name", required=True)
args = parser.parse_args()

print("Argument 1(model_name): %s" % args.model_name)
print("Argument 2(model_path): %s" % args.model_path)
print("Argument 3(dataset_name): %s" % args.dataset_name)

run = Run.get_context()
ws = None
if type(run) == _OfflineRun:
    ws = Workspace.from_config()
else:
    ws = run.experiment.workspace

train_ds = Dataset.get_by_name(ws, args.dataset_name)
datasets = [(Dataset.Scenario.TRAINING, train_ds)]

model = Model.register(workspace=ws,
                       model_path=args.model_path,
                       model_name=args.model_name,
                       datasets=datasets)

print("Registered version {0} of model {1}".format(model.version, model.name))
# Out:
# Overwriting AutoML_Retraining/AutoML_Model_Registration.py

# %%
register_model_step = PythonScriptStep(script_name="AutoML_Model_Registration.py",
                                       source_directory = 'AutoML_Retraining',
                                       name="Register_AutoML_Model",
                                       allow_reuse=False,
                                       arguments=["--model_name", model_name, "--model_path", model_data,
                                                  "--dataset_name", dataset_name],
                                       inputs=[model_data],
                                       compute_target=compute_target,
                                       runconfig=run_config)

# %% [markdown]
# ### Run your Dataset Registration Pipeline

# %%
# Create your pipeline
from azureml.pipeline.core import Pipeline, StepSequence
step_sequence = StepSequence(steps=[register_dataset_step, automl_step, register_model_step])
pipeline = Pipeline(workspace=ws, steps=step_sequence)
# Out:
# WARNING - 'azureml-defaults' is not included in the pip package list in the environment definition in RunConfiguration. This may result in job failures during execution.

# %%
# Run your pipeline
experiment_name = 'AutoML-Titanic-Pipeline'
pipeline_run = Experiment(ws, experiment_name).submit(pipeline,pipeline_parameters={}, show_output=True)
# Out:
# Created step Register_AutoML_Dataset [1a08c9e4][79650234-ef5b-4ad6-a69d-e4069fc12ae1], (This step will run and generate new outputs)Created step automl_module [bf1b9ce5][37219641-1ede-4917-bbd9-9a4a704dd0da], (This step will run and generate new outputs)
# Created step Register_AutoML_Model [ec52edc6][dbdf7f63-b674-4f52-b671-252291397df2], (This step will run and generate new outputs)
#
# Submitted PipelineRun 8efe12aa-660a-444b-8df3-39b1572555c3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/AutoML-Titanic-Pipeline/runs/8efe12aa-660a-444b-8df3-39b1572555c3?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/ml-teaching/workspaces/ml-teaching-workspace

# %%
# GUI to see your Pipeline Run
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 8efe12aa-660a-444b-8df3-39b1572555c3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/AutoML-Titanic-Pipeline/runs/8efe12aa-660a-444b-8df3-39b1572555c3?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/ml-teaching/workspaces/ml-teaching-workspace
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 06c74e49-1577-4859-967d-277b4185723f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/AutoML-Titanic-Pipeline/runs/06c74e49-1577-4859-967d-277b4185723f?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/ml-teaching/workspaces/ml-teaching-workspace
# StepRun( Register_AutoML_Dataset ) Status: NotStarted
# StepRun( Register_AutoML_Dataset ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_e3a60113670fd1f1fc642ad0361759fd77047cf292b32824b19d4c4d63eddd94_p.txt
# ========================================================================================================================
# 2020-07-08T20:26:37Z Starting output-watcher...
# 2020-07-08T20:26:37Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# aa2d50539065428c03617fafdb1c5a64dee30aa113d414c7a10e152e6ba95120
#
# Streaming azureml-logs/65_job_prep-tvmps_e3a60113670fd1f1fc642ad0361759fd77047cf292b32824b19d4c4d63eddd94_p.txt
# ===============================================================================================================
# [2020-07-08T20:26:39.938779] Entering job preparation.
# [2020-07-08T20:26:41.027689] Starting job preparation.
# [2020-07-08T20:26:41.027737] Extracting the control code.
# [2020-07-08T20:26:41.083617] fetching and extracting the control code on master node.
# [2020-07-08T20:26:42.718565] Retrieving project from snapshot: 68f9112e-2bcb-4554-bbac-bebc0ace247a
# Starting the daemon thread to refresh tokens in background for process with pid = 56
# [2020-07-08T20:26:42.720000] Start RetrieveProjectSasUrls
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/07/08 20:26:45 Starting App Insight Logger for task:  runTaskLet
# [2020-07-08T20:26:47.271170] Entering context manager injector.
# Starting the daemon thread to refresh tokens in background for process with pid = 114
# Entering Run History Context Manager.
# Preparing to call script [ AutoML_Dataset_Registration.py ] with arguments: ['--datastore_name', 'teaching_datalake', '--dataset_name', 'titanic_training_transformed_automl']
# After variable expansion, calling script [ AutoML_Dataset_Registration.py ] with arguments: ['--datastore_name', 'teaching_datalake', '--dataset_name', 'titanic_training_transformed_automl']
#
# Argument 1(datastore_name): teaching_datalake
# Argument 2(dataset_name): titanic_training_transformed_automl
# Datastore Set
# /azureml-envs/azureml_0a530854bb4b545b927025dea4605599/lib/python3.6/site-packages/azureml/dataprep/api/dataflow.py:722: UserWarning: Your pandas and pyarrow versions are incompatible. Please install pyarrow>=0.12.0 for improved performance of to_pandas_dataframe. You can ensure the correct version is installed by running: pip install pyarrow>=0.12.0 --upgrade
#   warnings.warn('Your pandas and pyarrow versions are incompatible. '
# Dataset Registered
# Starting the daemon thread to refresh tokens in background for process with pid = 114
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.1596982479095459 seconds
#
# Streaming azureml-logs/75_job_post-tvmps_e3a60113670fd1f1fc642ad0361759fd77047cf292b32824b19d4c4d63eddd94_p.txt
# ===============================================================================================================
# Entering job release. Current time:2020-07-08T20:27:14.184620
# Starting job release. Current time:2020-07-08T20:27:15.310265
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 302
# [2020-07-08T20:27:15.337003] Entering context manager injector.
# Job release is complete. Current time:2020-07-08T20:27:17.341063
#
# StepRun(Register_AutoML_Dataset) Execution Summary
# ===================================================
# StepRun( Register_AutoML_Dataset ) Status: Finished
# {'runId': '06c74e49-1577-4859-967d-277b4185723f', 'target': 'lp-training', 'status': 'Completed', 'startTimeUtc': '2020-07-08T20:26:27.571472Z', 'endTimeUtc': '2020-07-08T20:27:21.20544Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '68f9112e-2bcb-4554-bbac-bebc0ace247a', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '79650234-ef5b-4ad6-a69d-e4069fc12ae1', 'azureml.pipelinerunid': '8efe12aa-660a-444b-8df3-39b1572555c3', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '7cd06cfc-ec21-460b-b98f-b19ef97323c0'}, 'consumptionDetails': {'type': 'Reference'}}], 'runDefinition': {'script': 'AutoML_Dataset_Registration.py', 'useAbsolutePath': False, 'arguments': ['--datastore_name', 'teaching_datalake', '--dataset_name', 'titanic_training_transformed_automl'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'lp-training', 'dataReferences': {}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment AutoML-Titanic-Pipeline Environment', 'version': 'Autosave_2020-07-08T20:09:38Z_7fb4cee7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['--index-url https://azuremlsdktestpypi.azureedge.net/datasets_uploading', '--extra-index-url https://pypi.python.org/simple', 'azureml-core~=1.9.0', 'azureml-dataprep']}, 'numpy==1.16.2', 'pandas==0.23.4'], 'name': 'azureml_0a530854bb4b545b927025dea4605599'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_e3a60113670fd1f1fc642ad0361759fd77047cf292b32824b19d4c4d63eddd94_p.txt': 'https://mlteachingwork0962888719.blob.core.windows.net/azureml/ExperimentRun/dcid.06c74e49-1577-4859-967d-277b4185723f/azureml-logs/55_azureml-execution-tvmps_e3a60113670fd1f1fc642ad0361759fd77047cf292b32824b19d4c4d63eddd94_p.txt?sv=2019-02-02&sr=b&sig=UDnuGpPxa4n3SSWU1ng5dasooZferoz5YMzXwcB7x%2BQ%3D&st=2020-07-08T20%3A17%3A23Z&se=2020-07-09T04%3A27%3A23Z&sp=r', 'azureml-logs/65_job_prep-tvmps_e3a60113670fd1f1fc642ad0361759fd77047cf292b32824b19d4c4d63eddd94_p.txt': 'https://mlteachingwork0962888719.blob.core.windows.net/azureml/ExperimentRun/dcid.06c74e49-1577-4859-967d-277b4185723f/azureml-logs/65_job_prep-tvmps_e3a60113670fd1f1fc642ad0361759fd77047cf292b32824b19d4c4d63eddd94_p.txt?sv=2019-02-02&sr=b&sig=O6m19AbhbjODoPmoXWrv8Bzj7nUi50NU%2BCLqTwWDEe8%3D&st=2020-07-08T20%3A17%3A23Z&se=2020-07-0 ...
#
#
#
#
# StepRunId: 24a2543d-7f43-41e2-bae8-c945a0b99c77
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/AutoML-Titanic-Pipeline/runs/24a2543d-7f43-41e2-bae8-c945a0b99c77?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/ml-teaching/workspaces/ml-teaching-workspace
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fba5176af28>: Failed to establish a new connection: [Errno 111] Connection refused',)': /history/v1.0/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourceGroups/ml-teaching/providers/Microsoft.MachineLearningServices/workspaces/ml-teaching-workspace/experiments/AutoML-Titanic-Pipeline/runs/24a2543d-7f43-41e2-bae8-c945a0b99c77/details
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '24a2543d-7f43-41e2-bae8-c945a0b99c77', 'target': 'lp-training', 'status': 'Completed', 'startTimeUtc': '2020-07-08T20:46:52.903704Z', 'endTimeUtc': '2020-07-08T21:13:49.650026Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '22644860-97db-45c0-9a38-47b09b720639', 'StepType': 'AutoMLStep', 'azureml.moduleid': '37219641-1ede-4917-bbd9-9a4a704dd0da', 'azureml.pipelinerunid': '8efe12aa-660a-444b-8df3-39b1572555c3', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'accuracy', 'train_split': '0', 'MaxTimeSeconds': '900', 'acquisition_parameter': '0', 'num_cross_validation': '3', 'target': 'lp-training', 'RawAMLSettingsString': "{'path': '.', 'name': 'placeholder', 'subscription_id': '47a7ec0c-37ad-428b-9114-b87ea1057632', 'resource_group': 'ml-teaching', 'workspace_name': 'ml-teaching-workspace', 'region': 'centralus', 'compute_target': None, 'spark_service': None, 'azure_service': None, '_local_managed_run_id': None, 'iterations': 1000, 'primary_metric': 'accuracy', 'task_type': 'classification', 'data_script': None, 'validation_size': 0.0, 'n_cross_validations': 3, 'y_min': None, 'y_max': None, 'num_classes': None, 'featurization': 'auto', '_ignore_package_version_incompatibilities': False, 'is_timeseries': False, 'max_cores_per_iteration': -1, 'max_concurrent_iterations': 3, 'iteration_timeout_minutes': 15, 'mem_in_mb': None, 'enforce_time_on_windows': False, 'experiment_timeout_minutes': 30, 'experiment_exit_score': None, 'whitelist_models': None, 'blacklist_algos': None, 'supported_models': ['BernoulliNaiveBayes', 'RandomForest', 'TensorFlowDNN', 'ExtremeRandomTrees', 'LightGBM', 'SGD', 'TensorFlowLinearClassifier', 'MultinomialNaiveBayes', 'KNN', 'AveragedPerceptronClassifier', 'XGBoostClassifier', 'SVM', 'LogisticRegression', 'GradientBoosting', 'LinearSVM', 'DecisionTree'], 'auto_blacklist': True, 'blacklist_samples_reached': False, 'exclude_nan_labels': True, 'verbosity': 20, '_debug_log': 'automl_errors.log', 'show_warnings': False, 'model_explainability': True, 'service_url': None, 'sdk_url': None, 'sdk_packages': None, 'enable_onnx_compatible_models': False, 'enable_split_onnx_featurizer_estimator_models': False, 'vm_type': 'STANDARD_DS3_V2', 'telemetry_verbosity': 20, 'send_telemetry': True, 'enable_dnn': False, 'force_text_dnn': False, 'enable_feature_sweeping': True, 'enable_early_stopping': True, 'early_stopping_n_iters': 10, 'metrics': None, 'enable_ensembling': True, 'enable_stack_ensembling': True, 'ensemble_iterations': 15, 'enable_tf': False, 'enable_subsampling': None, 'subsample_seed': None, 'enable_nimbusml': False, 'enable_streaming': False, 'force_streaming': False, 'track_child_runs': True, 'label_column_name': 'Survived', 'weight_column_name': None, 'cv_split_column_names': None, 'enable_local_managed': False, 'cost_mode': 1, 'lag_length': 0, 'metric_operation': 'maximize', 'preprocess': True, 'scenario': 'SDK-Compatible'}", 'AMLSettingsJsonString': '{"path": ".", "name": "placeholder", "subscription_id": "47a7ec0c-37ad-428b-9114-b87ea1057632", "resource_group": "ml-teaching", "workspace_name": "ml-teaching-workspace", "region": "centralus", "compute_target": null, "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "iterations": 1000, "primary_metric": "accuracy", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": 3, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": -1, "max_concurrent_iterations": 3, "iteration_timeout_minutes": 15, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 30, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["BernoulliNaiveBayes", "RandomForest", "TensorFlowDNN", "ExtremeRando ...
#
#
#
#
# StepRunId: 2e5f3253-b096-43f4-b9af-aff17d08af37
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/AutoML-Titanic-Pipeline/runs/2e5f3253-b096-43f4-b9af-aff17d08af37?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/ml-teaching/workspaces/ml-teaching-workspace
# StepRun( Register_AutoML_Model ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/07/08 21:23:31 Downloading source code...
# 2020/07/08 21:23:32 Finished downloading source code
# StepRun( Register_AutoML_Model ) Status: Running
# 2020/07/08 21:23:33 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/07/08 21:23:33 Successfully set up Docker network: acb_default_network
# 2020/07/08 21:23:33 Setting up Docker configuration...
# 2020/07/08 21:23:34 Successfully set up Docker configuration
# 2020/07/08 21:23:34 Logging in to registry: mlteachingwoe1b28e33.azurecr.io
# 2020/07/08 21:23:35 Successfully logged into mlteachingwoe1b28e33.azurecr.io
# 2020/07/08 21:23:35 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/07/08 21:23:35 Scanning for dependencies...
# 2020/07/08 21:23:36 Successfully scanned dependencies
# 2020/07/08 21:23:36 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# Digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#  ---> a0dab4f7c804
# Step 2/15 : USER root
#  ---> Running in 4c9186e93945
# Removing intermediate container 4c9186e93945
#  ---> 2894143a64a8
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 15e63aa0754c
# Removing intermediate container 15e63aa0754c
#  ---> c6c37bb0a44f
# Step 4/15 : WORKDIR /
#  ---> Running in 05446e2f99e2
# Removing intermediate container 05446e2f99e2
#  ---> 01d8f0a0f657
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 1bb01dc65954
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in f6e5c99c9060
# Removing intermediate container f6e5c99c9060
#  ---> 6d2309bd75ab
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 1319ba3efd05
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_778c0158c725f306919e19e0e36767df -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 4498564a0514
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# _py-xgboost-mutex-2. | 9 KB      |            |   0%
# _py-xgboost-mutex-2. | 9 KB      | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | 4          |   5%
# icu-58.2             | 22.7 MB   | ###7       |  37%
# icu-58.2             | 22.7 MB   | #######1   |  71%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# lunardate-0.2.0      | 21 KB     |            |   0%
# lunardate-0.2.0      | 21 KB     | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #6         |  16%
# python-3.6.2         | 27.0 MB   | ####5      |  46%
# python-3.6.2         | 27.0 MB   | #######    |  71%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# scikit-learn-0.20.3  | 5.7 MB    |            |   0%
# scikit-learn-0.20.3  | 5.7 MB    | ########9  |  89%
# scikit-learn-0.20.3  | 5.7 MB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# pymeeus-0.3.7        | 515 KB    |            |   0%
# pymeeus-0.3.7        | 515 KB    | ########## | 100%
#
# psutil-5.7.0         | 332 KB    |            |   0%
# psutil-5.7.0         | 332 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# matplotlib-base-3.2. | 7.2 MB    |            |   0%
# matplotlib-base-3.2. | 7.2 MB    | ########4  |  85%
# matplotlib-base-3.2. | 7.2 MB    | ########## | 100%
#
# gxx_linux-64-7.3.0   | 24 KB     |            |   0%
# gxx_linux-64-7.3.0   | 24 KB     | ########## | 100%
#
# libxgboost-0.90      | 3.8 MB    |            |   0%
# libxgboost-0.90      | 3.8 MB    | ########6  |  87%
# libxgboost-0.90      | 3.8 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 3          |   4%
# qt-5.9.6             | 86.7 MB   | #3         |  13%
# qt-5.9.6             | 86.7 MB   | ##2        |  22%
# qt-5.9.6             | 86.7 MB   | ###        |  31%
# qt-5.9.6             | 86.7 MB   | ###9       |  39%
# qt-5.9.6             | 86.7 MB   | ####7      |  48%
# qt-5.9.6             | 86.7 MB   | #####6     |  57%
# qt-5.9.6             | 86.7 MB   | ######5    |  66%
# qt-5.9.6             | 86.7 MB   | #######4   |  75%
# qt-5.9.6             | 86.7 MB   | ########3  |  84%
# qt-5.9.6             | 86.7 MB   | #########2 |  93%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# binutils_impl_linux- | 16.5 MB   |            |   0%
# binutils_impl_linux- | 16.5 MB   | ##8        |  28%
# binutils_impl_linux- | 16.5 MB   | #######6   |  76%
# binutils_impl_linux- | 16.5 MB   | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# freetype-2.10.2      | 915 KB    |            |   0%
# freetype-2.10.2      | 915 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ####8      |  49%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# sip-4.19.23          | 299 KB    |            |   0%
# sip-4.19.23          | 299 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# matplotlib-3.2.2     | 20 KB     |            |   0%
# matplotlib-3.2.2     | 20 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | #########9 |  99%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 1          |   2%
# mkl-2019.4           | 204.1 MB  | 5          |   6%
# mkl-2019.4           | 204.1 MB  | 9          |  10%
# mkl-2019.4           | 204.1 MB  | #3         |  14%
# mkl-2019.4           | 204.1 MB  | #7         |  18%
# mkl-2019.4           | 204.1 MB  | ##1        |  22%
# mkl-2019.4           | 204.1 MB  | ##5        |  26%
# mkl-2019.4           | 204.1 MB  | ##9        |  30%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####2      |  42%
# mkl-2019.4           | 204.1 MB  | ####6      |  47%
# mkl-2019.4           | 204.1 MB  | #####1     |  51%
# mkl-2019.4           | 204.1 MB  | #####5     |  56%
# mkl-2019.4           | 204.1 MB  | ######     |  60%
# mkl-2019.4           | 204.1 MB  | ######4    |  64%
# mkl-2019.4           | 204.1 MB  | ######8    |  69%
# mkl-2019.4           | 204.1 MB  | #######2   |  73%
# mkl-2019.4           | 204.1 MB  | #######7   |  77%
# mkl-2019.4           | 204.1 MB  | ########1  |  82%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# binutils_linux-64-2. | 24 KB     |            |   0%
# binutils_linux-64-2. | 24 KB     | ########## | 100%
#
# pip-20.1.1           | 2.0 MB    |            |   0%
# pip-20.1.1           | 2.0 MB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# scipy-1.5.0          | 18.6 MB   |            |   0%
# scipy-1.5.0          | 18.6 MB   | #8         |  19%
# scipy-1.5.0          | 18.6 MB   | ###9       |  39%
# scipy-1.5.0          | 18.6 MB   | #######3   |  74%
# scipy-1.5.0          | 18.6 MB   | ########## | 100%
#
# py-xgboost-0.90      | 77 KB     |            |   0%
# py-xgboost-0.90      | 77 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# gcc_impl_linux-64-7. | 73.2 MB   |            |   0%
# gcc_impl_linux-64-7. | 73.2 MB   | 6          |   6%
# gcc_impl_linux-64-7. | 73.2 MB   | #7         |  17%
# gcc_impl_linux-64-7. | 73.2 MB   | ##8        |  29%
# gcc_impl_linux-64-7. | 73.2 MB   | ###7       |  37%
# gcc_impl_linux-64-7. | 73.2 MB   | ####6      |  47%
# gcc_impl_linux-64-7. | 73.2 MB   | #####7     |  58%
# gcc_impl_linux-64-7. | 73.2 MB   | ######7    |  67%
# gcc_impl_linux-64-7. | 73.2 MB   | #######6   |  77%
# gcc_impl_linux-64-7. | 73.2 MB   | ########8  |  88%
# gcc_impl_linux-64-7. | 73.2 MB   | #########8 |  99%
# gcc_impl_linux-64-7. | 73.2 MB   | ########## | 100%
#
# cython-0.29.20       | 2.1 MB    |            |   0%
# cython-0.29.20       | 2.1 MB    | ########## | 100%
#
# gxx_impl_linux-64-7. | 18.7 MB   |            |   0%
# gxx_impl_linux-64-7. | 18.7 MB   | ##5        |  25%
# gxx_impl_linux-64-7. | 18.7 MB   | #######5   |  76%
# gxx_impl_linux-64-7. | 18.7 MB   | ########## | 100%
#
# numpy-1.16.2         | 49 KB     |            |   0%
# numpy-1.16.2         | 49 KB     | ########## | 100%
#
# ca-certificates-2020 | 133 KB    |            |   0%
# ca-certificates-2020 | 133 KB    | ########## | 100%
#
# fbprophet-0.5        | 631 KB    |            |   0%
# fbprophet-0.5        | 631 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# pystan-2.19.0.0      | 16.6 MB   |            |   0%
# pystan-2.19.0.0      | 16.6 MB   | ###5       |  36%
# pystan-2.19.0.0      | 16.6 MB   | #########8 |  98%
# pystan-2.19.0.0      | 16.6 MB   | ########## | 100%
#
# numpy-base-1.16.2    | 4.4 MB    |            |   0%
# numpy-base-1.16.2    | 4.4 MB    | #########9 |  99%
# numpy-base-1.16.2    | 4.4 MB    | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ######1    |  62%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# dbus-1.13.12         | 611 KB    |            |   0%
# dbus-1.13.12         | 611 KB    | ########## | 100%
#
# pandas-0.23.4        | 10.1 MB   |            |   0%
# pandas-0.23.4        | 10.1 MB   | ####4      |  45%
# pandas-0.23.4        | 10.1 MB   | ########## | 100%
#
# intel-openmp-2020.1  | 940 KB    |            |   0%
# intel-openmp-2020.1  | 940 KB    | ########## | 100%
#
# gcc_linux-64-7.3.0   | 25 KB     |            |   0%
# gcc_linux-64-7.3.0   | 25 KB     | ########## | 100%
#
# expat-2.2.9          | 196 KB    |            |   0%
# expat-2.2.9          | 196 KB    | ########## | 100%
#
# setuptools-47.3.1    | 647 KB    |            |   0%
# setuptools-47.3.1    | 647 KB    | ########## | 100%
#
# mkl_fft-1.1.0        | 159 KB    |            |   0%
# mkl_fft-1.1.0        | 159 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# convertdate-2.2.1    | 33 KB     |            |   0%
# convertdate-2.2.1    | 33 KB     | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# holidays-0.9.11      | 39 KB     |            |   0%
# holidays-0.9.11      | 39 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_778c0158c725f306919e19e0e36767df/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt']
# Pip subprocess output:
# Collecting azureml-train-automl-runtime==1.8.0.post1
#   Downloading azureml_train_automl_runtime-1.8.0.post1-py3-none-any.whl (88 kB)
# Collecting inference-schema
#   Downloading inference_schema-1.0.2-py3-none-any.whl (19 kB)
# Collecting azureml-explain-model==1.8.0
#   Downloading azureml_explain_model-1.8.0-py3-none-any.whl (22 kB)
# Collecting azureml-defaults==1.8.0
#   Downloading azureml_defaults-1.8.0-py3-none-any.whl (3.0 kB)
# Collecting scipy<=1.4.1,>=1.0.0
#   Downloading scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
# Requirement already satisfied, skipping upgrade: numpy<=1.16.2,>=1.16.0 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (1.16.2)
# Collecting azureml-telemetry~=1.8.0
#   Downloading azureml_telemetry-1.8.0-py3-none-any.whl (29 kB)
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
# Collecting smart-open<=1.9.0
#   Downloading smart_open-1.9.0.tar.gz (70 kB)
# Collecting keras2onnx<=1.6.0,>=1.4.0
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
# Collecting statsmodels<=0.10.2,>=0.9.0
#   Downloading statsmodels-0.10.2-cp36-cp36m-manylinux1_x86_64.whl (8.1 MB)
# Collecting sklearn-pandas<=1.7.0,>=1.4.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting gensim<3.9.0
#   Downloading gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2 MB)
# Collecting azureml-automl-runtime~=1.8.0
#   Downloading azureml_automl_runtime-1.8.0-py3-none-any.whl (1.9 MB)
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
# Collecting azureml-dataprep[fuse,pandas]<1.9.0a,>=1.8.0a
#   Downloading azureml_dataprep-1.8.3-py3-none-any.whl (27.7 MB)
# Collecting onnx<=1.6.0,>=1.5.0
#   Downloading onnx-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (4.8 MB)
# Requirement already satisfied, skipping upgrade: scikit-learn<=0.20.3,>=0.19.0 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (0.20.3)
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
# Collecting lightgbm<=2.3.0,>=2.0.11
#   Downloading lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-automl-core~=1.8.0
#   Downloading azureml_automl_core-1.8.0-py3-none-any.whl (132 kB)
# Requirement already satisfied, skipping upgrade: pandas<=0.23.4,>=0.21.0 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (0.23.4)
# Collecting azureml-core~=1.8.0
#   Downloading azureml_core-1.8.0.post1-py3-none-any.whl (1.5 MB)
# Collecting onnxruntime==1.0.0
#   Downloading onnxruntime-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (3.4 MB)
# Collecting azureml-train-automl-client~=1.8.0
#   Downloading azureml_train_automl_client-1.8.0-py3-none-any.whl (89 kB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from inference-schema->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 2)) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from inference-schema->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 2)) (2.8.1)
# Collecting wrapt==1.11.1
#   Downloading wrapt-1.11.1.tar.gz (27 kB)
# Collecting azureml-interpret~=1.8.0
#   Downloading azureml_interpret-1.8.0-py3-none-any.whl (47 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting protobuf
#   Downloading protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Requirement already satisfied, skipping upgrade: six in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from onnxmltools==1.4.1->azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (1.15.0)
# Collecting boto>=2.32
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Collecting requests
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting boto3
#   Downloading boto3-1.14.19-py2.py3-none-any.whl (128 kB)
# Collecting fire
#   Downloading fire-0.3.1.tar.gz (81 kB)
# Collecting patsy>=0.4.0
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting nimbusml==1.7.1
#   Downloading nimbusml-1.7.1-cp36-none-manylinux1_x86_64.whl (116.2 MB)
# Collecting pmdarima==1.1.1
#   Downloading pmdarima-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (682 kB)
# Collecting dill<0.4.0,>=0.2.8
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting py-cpuinfo==5.0.0
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
# Collecting joblib==0.14.1
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
# Requirement already satisfied, skipping upgrade: psutil<6.0.0,>=5.2.2 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from azureml-automl-runtime~=1.8.0->azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (5.7.0)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.5.0-py3-none-any.whl (22 kB)
# Collecting azureml-dataprep-native<15.0.0,>=14.2.1
#   Downloading azureml_dataprep_native-14.2.1-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting pyarrow>=0.15.*; extra == "pandas"
#   Downloading pyarrow-0.17.1-cp36-cp36m-manylinux2014_x86_64.whl (63.8 MB)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-3.7.4.2-py3-none-any.whl (22 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting docker
#   Downloading docker-4.2.2-py2.py3-none-any.whl (144 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-11.1.0-py2.py3-none-any.whl (547 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.17-py2.py3-none-any.whl (84 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.1.0-py2.py3-none-any.whl (892 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting interpret-community==0.12.*
#   Downloading interpret_community-0.12.1-py3-none-any.whl (5.4 MB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied, skipping upgrade: setuptools in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from protobuf->onnxmltools==1.4.1->azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (47.3.1.post20200622)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from requests->smart-open<=1.9.0->azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (2020.6.20)
# Collecting botocore<1.18.0,>=1.17.19
#   Downloading botocore-1.17.19-py2.py3-none-any.whl (6.3 MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied, skipping upgrade: Cython>=0.29 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from pmdarima==1.1.1->azureml-automl-runtime~=1.8.0->azureml-train-automl-runtime==1.8.0.post1->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 1)) (0.29.20)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.4.1-py2.py3-none-any.whl (48 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.7.0-py2.py3-none-any.whl (121 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting shap<=0.34.0,>=0.20.0
#   Downloading shap-0.34.0.tar.gz (264 kB)
# Collecting interpret-core[required]<=0.1.21,>=0.1.20
#   Downloading interpret_core-0.1.21-py3-none-any.whl (8.3 MB)
# Collecting packaging
#   Downloading packaging-20.4-py2.py3-none-any.whl (37 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting tqdm>4.25.0
#   Downloading tqdm-4.47.0-py2.py3-none-any.whl (66 kB)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib/python3.6/site-packages (from packaging->interpret-community==0.12.*->azureml-interpret~=1.8.0->azureml-explain-model==1.8.0->-r /azureml-environment-setup/condaenv.y4cp6z7h.requirements.txt (line 3)) (2.4.7)
# Building wheels for collected packages: smart-open, wrapt, json-logging-py, fire, dill, py-cpuinfo, fusepy, liac-arff, termcolor, shap
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-1.9.0-py3-none-any.whl size=73085 sha256=a0f7e2f523974e34ab9e3736869e78a05c8a9e30153c1a62b15af9dcd2a00db1
#   Stored in directory: /root/.cache/pip/wheels/8e/9f/cd/dbf5c1362c59abb699a218c1151679033b8ccb5b6db559d512
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.11.1-py3-none-any.whl size=19543 sha256=e454234e36a8f8527f8b0a1aed5d96e76931823092642776eb5fb5c53c58471c
#   Stored in directory: /root/.cache/pip/wheels/94/0f/ec/66085641573800014bb0c8b657f3366eff641c42df79abbfe9
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=2e765709a3f1eaf11deb61ed02ad8181383e7d522ce8456323c7575d65e7a46d
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.3.1-py2.py3-none-any.whl size=111005 sha256=52d458cd5674ae7be7e7e70249cd80e9ad2b232582b13e32ba27ea73bf92ae45
#   Stored in directory: /root/.cache/pip/wheels/3e/38/8f/e5bd4465e4b72c8e4d1530ac46e1a42e1d2495f8c93242d5f1
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=c866019a9808001d4f455f743790454cb7553088889d08e1ad8a5537bc199c0d
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'done'
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18682 sha256=1f7889d977fd71e79a61a121ec3c50010696a38f97fc326214d68d2eaeae11e6
#   Stored in directory: /root/.cache/pip/wheels/e6/54/db/65176a1697a583d8ec5f90510f6faab11cda739d0e4f0ba2ea
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=329569194b22ee3a51651ffe1a6bc64383707bcba695864a165c49745d68595b
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=23a7b8418cf7d3e36622877ec9b1d8849090594805fc2404882675df80362819
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=459e1e99ea6142b1baf85cb9a3c3b9edd7aae01feb4ce2d037489f4ce68b6390
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.34.0-cp36-cp36m-linux_x86_64.whl size=383863 sha256=78c59f8b7c6a8e2b315c1681c82418f2c8b24b16490168526f797fcba3711fa1
#   Stored in directory: /root/.cache/pip/wheels/88/56/c6/630b200696678c506f3057a1e7573c086e50d59fdcffcbfd04
# Successfully built smart-open wrapt json-logging-py fire dill py-cpuinfo fusepy liac-arff termcolor shap
# ...
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_778c0158c725f306919e19e0e36767df
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fba51681320>: Failed to establish a new connection: [Errno 111] Connection refused',)': /history/v1.0/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourceGroups/ml-teaching/providers/Microsoft.MachineLearningServices/workspaces/ml-teaching-workspace/experiments/AutoML-Titanic-Pipeline/runs/2e5f3253-b096-43f4-b9af-aff17d08af37/details
# Removing intermediate container 4498564a0514
#  ---> e9383440d054
# Step 9/15 : ENV PATH /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/bin:$PATH
#  ---> Running in 55937092a3ad
# Removing intermediate container 55937092a3ad
#  ---> 82beb6a4c9bf
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_778c0158c725f306919e19e0e36767df
#  ---> Running in 2f251d01714a
# Removing intermediate container 2f251d01714a
#  ---> cdf7801f9526
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_778c0158c725f306919e19e0e36767df/lib:$LD_LIBRARY_PATH
#  ---> Running in 2d80c7f32bc5
# Removing intermediate container 2d80c7f32bc5
#  ---> 6da251112a7a
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 398ebbd009ee
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 6da84cf6a5bc
# Removing intermediate container 6da84cf6a5bc
#  ---> 9c5bbb9316a0
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in a0029ad40889
# Removing intermediate container a0029ad40889
#  ---> 4cf979f8df37
# Step 15/15 : CMD ["bash"]
#  ---> Running in 0bef68e479cb
# Removing intermediate container 0bef68e479cb
#  ---> 53f3d65aaef4
# Successfully built 53f3d65aaef4
# Successfully tagged mlteachingwoe1b28e33.azurecr.io/azureml/azureml_15ad80e0a56b9227a7ab23b0a829d38a:latest
# 2020/07/08 21:31:15 Successfully executed container: acb_step_0
# 2020/07/08 21:31:15 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/07/08 21:31:15 Pushing image: mlteachingwoe1b28e33.azurecr.io/azureml/azureml_15ad80e0a56b9227a7ab23b0a829d38a:latest, attempt 1
# The push refers to repository [mlteachingwoe1b28e33.azurecr.io/azureml/azureml_15ad80e0a56b9227a7ab23b0a829d38a]
# d1dfdfb6ac50: Preparing
# 48157b4cb6d9: Preparing
# a6689bc8fda3: Preparing
# 536be424cdba: Preparing
# 36ca5b2ae0de: Preparing
# 09a50825b0da: Preparing
# f5aa53607bc1: Preparing
# 07eae5ad8c0b: Preparing
# facf43cddd83: Preparing
# 69a9bdc813b0: Preparing
# 7e2b9752143f: Preparing
# 63a67842a4c7: Preparing
# ae3a847dbd6b: Preparing
# 4ae3adcb66cb: Preparing
# aa6685385151: Preparing
# 0040d8f00d7e: Preparing
# 9e6f810a2aab: Preparing
# 7e2b9752143f: Waiting
# 63a67842a4c7: Waiting
# ae3a847dbd6b: Waiting
# 4ae3adcb66cb: Waiting
# aa6685385151: Waiting
# 0040d8f00d7e: Waiting
# 9e6f810a2aab: Waiting
# 09a50825b0da: Waiting
# f5aa53607bc1: Waiting
# 07eae5ad8c0b: Waiting
# 69a9bdc813b0: Waiting
# facf43cddd83: Waiting
# a6689bc8fda3: Pushed
# d1dfdfb6ac50: Pushed
# 36ca5b2ae0de: Pushed
# 536be424cdba: Pushed
# 09a50825b0da: Pushed
# f5aa53607bc1: Pushed
# 07eae5ad8c0b: Pushed
# 63a67842a4c7: Pushed
# 7e2b9752143f: Pushed
# facf43cddd83: Pushed
# 4ae3adcb66cb: Pushed
# 69a9bdc813b0: Pushed
# aa6685385151: Pushed
# 0040d8f00d7e: Pushed
#
# ae3a847dbd6b: Pushed
# 9e6f810a2aab: Pushed
# 48157b4cb6d9: Pushed
# latest: digest: sha256:476344724b046c5c96f41514ddf0a9f646900811b755f0dc306f216121629c58 size: 3884
# 2020/07/08 21:35:42 Successfully pushed image: mlteachingwoe1b28e33.azurecr.io/azureml/azureml_15ad80e0a56b9227a7ab23b0a829d38a:latest
# 2020/07/08 21:35:42 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 460.057823)
# 2020/07/08 21:35:42 Populating digests for step ID: acb_step_0...
# 2020/07/08 21:35:44 Successfully populated digests for step ID: acb_step_0
# 2020/07/08 21:35:44 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 267.555856)
# 2020/07/08 21:35:44 The following dependencies were found:
# 2020/07/08 21:35:44
# - image:
#     registry: mlteachingwoe1b28e33.azurecr.io
#     repository: azureml/azureml_15ad80e0a56b9227a7ab23b0a829d38a
#     tag: latest
#     digest: sha256:476344724b046c5c96f41514ddf0a9f646900811b755f0dc306f216121629c58
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200423.v1
#     digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#   git: {}
#
#
# Run ID: cjc was successful after 12m14s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_9e87cd42f2bcba117c6549f38d91471afc4e21b0b45be0e1d8d24d497b2d6943_p.txt
# ========================================================================================================================
# 2020-07-08T21:37:09Z Starting output-watcher...
# 2020-07-08T21:37:09Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# 0ec9817498758a649db840fa6e90872c80274009f67f97e0fb579dcdabbc3488
#
# Streaming azureml-logs/65_job_prep-tvmps_9e87cd42f2bcba117c6549f38d91471afc4e21b0b45be0e1d8d24d497b2d6943_p.txt
# ===============================================================================================================
# [2020-07-08T21:38:14.744425] Entering job preparation.
# [2020-07-08T21:38:15.892395] Starting job preparation.
# [2020-07-08T21:38:15.892424] Extracting the control code.
# [2020-07-08T21:38:15.944845] fetching and extracting the control code on master node.
# [2020-07-08T21:38:17.473013] Retrieving project from snapshot: 8fd95099-1a59-42c2-a767-7f2678db9230
# Starting the daemon thread to refresh tokens in background for process with pid = 57
# [2020-07-08T21:38:17.474820] Start RetrieveProjectSasUrls
# [2020-07-08T21:38:18.071828] Finished RetrieveProjectSasUrls
# [2020-07-08T21:38:18.073162] Starting project file download.
# [2020-07-08T21:38:18.439824] Finished project file download.
# [2020-07-08T21:38:18.462554] Finished fetching and extracting the control code.
# [2020-07-08T21:38:18.465264] downloadDataStore - Download from datastores if requested.
# [2020-07-08T21:38:18.466085] Start run_history_prep.
# [2020-07-08T21:38:18.569737] Entering context manager injector.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/07/08 21:38:21 Starting App Insight Logger for task:  runTaskLet
# [2020-07-08T21:38:23.647365] Entering context manager injector.
# Starting the daemon thread to refresh tokens in background for process with pid = 124
# Entering Run History Context Manager.
# Preparing to call script [ AutoML_Model_Registration.py ] with arguments: ['--model_name', 'AutoML_Titanic_Classification', '--model_path', '/mnt/batch/tasks/shared/LS_root/jobs/ml-teaching-workspace/azureml/2e5f3253-b096-43f4-b9af-aff17d08af37/mounts/teaching_datalake/azureml/24a2543d-7f43-41e2-bae8-c945a0b99c77/model_data', '--dataset_name', 'titanic_training_transformed_automl']
# After variable expansion, calling script [ AutoML_Model_Registration.py ] with arguments: ['--model_name', 'AutoML_Titanic_Classification', '--model_path', '/mnt/batch/tasks/shared/LS_root/jobs/ml-teaching-workspace/azureml/2e5f3253-b096-43f4-b9af-aff17d08af37/mounts/teaching_datalake/azureml/24a2543d-7f43-41e2-bae8-c945a0b99c77/model_data', '--dataset_name', 'titanic_training_transformed_automl']
#
# Argument 1(model_name): AutoML_Titanic_Classification
# Argument 2(model_path): /mnt/batch/tasks/shared/LS_root/jobs/ml-teaching-workspace/azureml/2e5f3253-b096-43f4-b9af-aff17d08af37/mounts/teaching_datalake/azureml/24a2543d-7f43-41e2-bae8-c945a0b99c77/model_data
# Argument 3(dataset_name): titanic_training_transformed_automl
# Registering model AutoML_Titanic_Classification
# Registered version 2 of model AutoML_Titanic_Classification
# Starting the daemon thread to refresh tokens in background for process with pid = 124
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.15586471557617188 seconds
#
# Streaming azureml-logs/75_job_post-tvmps_9e87cd42f2bcba117c6549f38d91471afc4e21b0b45be0e1d8d24d497b2d6943_p.txt
# ===============================================================================================================
# Entering job release. Current time:2020-07-08T21:38:34.739896
# Starting job release. Current time:2020-07-08T21:38:36.961842
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 169
# [2020-07-08T21:38:36.986338] Entering context manager injector.
# Job release is complete. Current time:2020-07-08T21:38:38.639064
#
# StepRun(Register_AutoML_Model) Execution Summary
# =================================================
# StepRun( Register_AutoML_Model ) Status: Finished
# {'runId': '2e5f3253-b096-43f4-b9af-aff17d08af37', 'target': 'lp-training', 'status': 'Completed', 'startTimeUtc': '2020-07-08T21:36:54.764569Z', 'endTimeUtc': '2020-07-08T21:38:43.162611Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '8fd95099-1a59-42c2-a767-7f2678db9230', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'dbdf7f63-b674-4f52-b671-252291397df2', 'azureml.pipelinerunid': '8efe12aa-660a-444b-8df3-39b1572555c3', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '7cd06cfc-ec21-460b-b98f-b19ef97323c0'}, 'consumptionDetails': {'type': 'Reference'}}], 'runDefinition': {'script': 'AutoML_Model_Registration.py', 'useAbsolutePath': False, 'arguments': ['--model_name', 'AutoML_Titanic_Classification', '--model_path', '$AZUREML_DATAREFERENCE_model_data', '--dataset_name', 'titanic_training_transformed_automl'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'lp-training', 'dataReferences': {'model_data': {'dataStoreName': 'teaching_datalake', 'mode': 'Mount', 'pathOnDataStore': 'azureml/24a2543d-7f43-41e2-bae8-c945a0b99c77/model_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment AutoML-Titanic-Pipeline Environment', 'version': 'Autosave_2020-07-08T21:23:28Z_90eaaa5e', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-train-automl-runtime==1.8.0.post1', 'inference-schema', 'azureml-explain-model==1.8.0', 'azureml-defaults==1.8.0']}, 'numpy>=1.16.0,<=1.16.2', 'pandas>=0.21.0,<=0.23.4', 'scikit-learn>=0.19.0,<=0.20.3', 'py-xgboost<=0.90', 'fbprophet==0.5', 'psutil>=5.2.2,<6.0.0'], 'name': 'azureml_778c0158c725f306919e19e0e36767df'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mlteachingwork0962888719.blob.core.windows.net/azureml/ExperimentRun/dcid.2e5f3253-b096-43f4-b9af-aff17d08af37/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=pY3lTpyiAUC33LACjjhyicsAzS%2BnzZ3ge%2Beqwq2P17g%3D&st=2020-07-08T21%3A28%3A46Z&se=2020-07-09T05%3A38%3A46Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_9e87cd42f2bcba117c6549f38d91471afc4e21b0b45be0e1d8d24d497b2d6943_p.txt': 'https://mlteachingwork0962888719.blob.core.windows.net/azureml/ExperimentRun/dcid.2e5f3253-b096-43f4-b9af-aff17d08af37/azureml-logs/55_azureml-execution-tv ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '8efe12aa-660a-444b-8df3-39b1572555c3', 'status': 'Completed', 'startTimeUtc': '2020-07-08T20:26:11.747641Z', 'endTimeUtc': '2020-07-08T21:38:45.473275Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlteachingwork0962888719.blob.core.windows.net/azureml/ExperimentRun/dcid.8efe12aa-660a-444b-8df3-39b1572555c3/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=lG85DgWwfOnonOKVOx5%2F9pKuNqoHtQSE%2FeLu9vZvWsU%3D&st=2020-07-08T21%3A28%3A47Z&se=2020-07-09T05%3A38%3A47Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlteachingwork0962888719.blob.core.windows.net/azureml/ExperimentRun/dcid.8efe12aa-660a-444b-8df3-39b1572555c3/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=H2RpIVuzWz5uXY1gFu87rX57ovEVIFM6LewL4EByeFw%3D&st=2020-07-08T21%3A28%3A47Z&se=2020-07-09T05%3A38%3A47Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlteachingwork0962888719.blob.core.windows.net/azureml/ExperimentRun/dcid.8efe12aa-660a-444b-8df3-39b1572555c3/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=8j17qTRlHD9a0xIVTFvFuh424zUxgRqzr14x35pVj5k%3D&st=2020-07-08T21%3A28%3A47Z&se=2020-07-09T05%3A38%3A47Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ### Publish your Pipeline

# %%
# Match the name to your pipeline experiment

experiment_name = 'AutoML-Titanic-Pipeline'
experiment = Experiment(ws,experiment_name)

pipeline_run = PipelineRun(experiment, '8efe12aa-660a-444b-8df3-39b1572555c3')

published_pipeline = pipeline_run.publish_pipeline(
    name="Titanic-AutoML-Training-Pipeline",\
    description="AutoML Classification Pipeline for ADF Use", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Titanic-AutoML-Training-Pipeline,
# Id: 6e1c02ac-164e-4bff-9d0e-eafbe85f11f5,
# Status: Active,
# Endpoint: https://centralus.api.azureml.ms/pipelines/v1.0/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourceGroups/ml-teaching/providers/Microsoft.MachineLearningServices/workspaces/ml-teaching-workspace/PipelineRuns/PipelineSubmit/6e1c02ac-164e-4bff-9d0e-eafbe85f11f5)

# %%
retrieved_experiment = Experiment(ws,'AutoML-Titanic-Pipeline')
pipeline_run_id = '8efe12aa-660a-444b-8df3-39b1572555c3'
retrieved_pipeline = PipelineRun(retrieved_experiment, pipeline_run_id)
